# %% [markdown]
# ## Photos ##

# %%
from IPython.display import Image, display

# %%
#French Bulldog
display(Image(url="https://t4.ftcdn.net/jpg/00/95/00/55/240_F_95005565_u8gLZrJFXV1t9Qw0Y0N1nSVI8Vl2wCMg.jpg", width=400))
# Out:
# <img src="https://t4.ftcdn.net/jpg/00/95/00/55/240_F_95005565_u8gLZrJFXV1t9Qw0Y0N1nSVI8Vl2wCMg.jpg" width="400"/>

# %%
# German Shephard
display(Image(url="https://www.akc.org/wp-content/uploads/2020/03/German-Shepherd-Dog-standing-stacked-in-profile-in-the-park-800x600.jpg", width=400))
# Out:
# <img src="https://www.akc.org/wp-content/uploads/2020/03/German-Shepherd-Dog-standing-stacked-in-profile-in-the-park-800x600.jpg" width="400"/>

# %%
# Poodle
display(Image(url="https://www.akc.org/wp-content/uploads/2023/02/Diana-the-Poodle.jpg", width=400))
# Out:
# <img src="https://www.akc.org/wp-content/uploads/2023/02/Diana-the-Poodle.jpg" width="400"/>

# %%
# Pomeranian
display(Image(url="https://money.com/wp-content/uploads/2024/03/Best-Small-Dog-Breeds-Pomeranian.jpg?quality=60", width=400))
# Out:
# <img src="https://money.com/wp-content/uploads/2024/03/Best-Small-Dog-Breeds-Pomeranian.jpg?quality=60" width="400"/>

# %%
# Shih Tzu
display(Image(url="https://money.com/wp-content/uploads/2024/03/Best-Small-Dog-Breeds-Shih-Tzu.jpg?quality=60", width=400))
# Out:
# <img src="https://money.com/wp-content/uploads/2024/03/Best-Small-Dog-Breeds-Shih-Tzu.jpg?quality=60" width="400"/>

# %%
# Alaskan Malamute
display(Image(url="https://cdn.britannica.com/02/236302-050-E1F61BB1/Alaskan-Malamute-sled-dog.jpg", width=400))
# Out:
# <img src="https://cdn.britannica.com/02/236302-050-E1F61BB1/Alaskan-Malamute-sled-dog.jpg" width="400"/>
